# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_data_model2 = pd.read_csv('avgword2vec_cbow.csv')

# %%
train_data_model2.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'train_id'], inplace=True)
train_data_model2
# Out:
#         item_condition_id  price  shipping         0         1         2  \
# 0                       2    8.0         1 -0.100559 -0.614330  0.208602
# 1                       3   14.0         0 -0.329170 -0.350506  0.272558
# 2                       1   25.0         1 -0.240003 -0.041858  0.145329
# 3                       3   25.0         0 -0.101531 -0.345377 -0.117154
# 4                       1   12.0         1  0.820777 -0.600387 -0.174789
# ...                   ...    ...       ...       ...       ...       ...
# 370407                  1   20.0         1  0.484753  0.030433 -0.842793
# 370408                  1   44.0         0 -0.989117 -0.492069 -0.002195
# 370409                  3   15.0         1  0.183705  0.060849  0.345536
# 370410                  1   16.0         0 -0.263113 -0.582247  0.410359
# 370411                  1   17.0         1 -1.829921 -0.804902  0.084474
#
#                3         4         5         6  ...       190       191  \
# ...

# %%
data = train_data_model2.copy()
from sklearn.model_selection import train_test_split

y = data['price']
X = data.drop(columns=['price'])


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
X_train = X_train[:10000]
y_train = y_train[:10000]
X_test = X_test[:3500]
y_test = y_test[:3500]

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components=100)
X_K_train = kpca.fit_transform(X_train)
X_K_test = kpca.transform(X_test)

# %%
import pickle

# Load the MLP model from file
filename = 'model1.pkl'
with open(filename, 'rb') as file:
    model1 = pickle.load(file)

# %%
import pickle

# Load the MLP model from file
filename = 'model2.pkl'
with open(filename, 'rb') as file:
    model2 = pickle.load(file)

# %%
import pickle

# Load the MLP model from file
filename = 'model3.pkl'
with open(filename, 'rb') as file:
    model3 = pickle.load(file)

# %%
import pickle

# Load the MLP model from file
filename = 'model4.pkl'
with open(filename, 'rb') as file:
    model4 = pickle.load(file)

# %%
import pickle

# Load the MLP model from file
filename = 'model5.pkl'
with open(filename, 'rb') as file:
    model5 = pickle.load(file)
# Out:
# [10:28:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.

# %%
import pickle

# Load the MLP model from file
filename = 'model6.pkl'
with open(filename, 'rb') as file:
    model6 = pickle.load(file)

# %%
plt.rcParams['lines.linewidth'] = 3

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y1[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y1[:100], label='Model 1', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value', zorder=2)
# Customize the plot
plt.title("Word2Vec(CBOW) - Multi-Layered Perceptron Regressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y2[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y2[:100], label='Model 2', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(CBOW) - Kernelized PCA - Multi-Layered Perceptron Regressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y3[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y3[:100], label='Model 3', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(CBOW) - Kernelized PCA - RandomizedSearchCV - Multi-Layered Perceptron Regressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y4[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y4[:100], label='Model 4', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(CBOW) - XGBRegressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y5[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y5[:100], label='Model 5', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(CBOW) - Kernelized PCA - XGBRegressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y6[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y6[:100], label='Model 6', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(CBOW) - Kernelized PCA - RandomizedSearchCV - XGBRegressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True)
x= [i for i in range(100)]
plt.scatter(x, y1[:100])
plt.scatter(x, y2[:100])
plt.scatter(x, y3[:100])
plt.plot(x, y1[:100], label='Model 1')
plt.plot(x, y2[:100], label='Model 2')
plt.plot(x, y3[:100], label='Model 3')
plt.plot(x, y_test[:100], label='Actual Value', zorder=3)

# Customize the plot
plt.title("Comparing All the Multi-Layered Perceptron Regressor Models.")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True)
x= [i for i in range(100)]
plt.scatter(x, y4[:100])
plt.scatter(x, y5[:100])
plt.scatter(x, y6[:100])
plt.plot(x, y4[:100], label='Model 4')
plt.plot(x, y5[:100], label='Model 5')
plt.plot(x, y6[:100], label='Model 6')
plt.plot(x, y_test[:100], label='Actual Value', zorder=3)

# Customize the plot
plt.title("Comparing All the XGBRegressor Models")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()
