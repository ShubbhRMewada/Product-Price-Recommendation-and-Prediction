# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_data_model2 = pd.read_csv('avgword2vec_sg.csv')

# %%
train_data_model2.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'train_id'], inplace=True)
train_data_model2
# Out:
#        item_condition_id  price  shipping         0         1         2  \
# 0                      4    6.0         1  0.037552  0.023915  0.005228
# 1                      1   38.0         0  0.232859 -0.038133  0.074237
# 2                      3   19.0         1 -0.033843 -0.001777 -0.164303
# 3                      3   13.0         1  0.277575 -0.176075  0.103876
# 4                      2   14.0         1  0.042444  0.112054  0.135623
# ...                  ...    ...       ...       ...       ...       ...
# 22220                  3   21.0         0 -0.074463  0.122469  0.416734
# 22221                  1   10.0         0  0.086083 -0.024563 -0.018871
# 22222                  1   10.0         0  0.146066 -0.121376  0.111775
# 22223                  1   12.0         0 -0.041727 -0.142778  0.097017
# 22224                  1   12.0         0  0.147853  0.040602 -0.105794
#
#               3         4         5         6  ...       190       191  \
# 0      0.024870  0.125262 -0.038266  0.113200  ...  0.261896  0.143941
# 1      0.100791  0.023038 -0.013040  0.028851  ...  0.251430  0.066081
# 2      0.292715  0.050827  0.184387  0.174933  ...  0.230903  0.064281
# 3      0.312039 -0.002630 -0.312623  0.096224  ...  0.320663  0.184249
# 4      0.246667  0.153029 -0.083521  0.179250  ...  0.271193  0.262207
# ...         ...       ...       ...       ...  ...       ...       ...
# 22220  0.020856  0.094992 -0.172024  0.144668  ...  0.089671 -0.003719
# 22221  0.173806  0.201046 -0.288738 -0.076850  ...  0.335237 -0.205561
# 22222  0.098236  0.063539  0.013970 -0.072577  ...  0.291403  0.053669
# 22223  0.209473 -0.015237 -0.066154 -0.294085  ...  0.369271  0.002607
# 22224  0.259467  0.137257 -0.029217  0.169930  ...  0.259493  0.163386
#
#             192       193       194       195       196       197       198  \
# 0     -0.128030  0.080459  0.144991  0.017747  0.205571 -0.201369 -0.035721
# 1      0.096789  0.106077 -0.000116  0.047183  0.072342 -0.355895 -0.056492
# 2      0.136571 -0.133916  0.242645 -0.154565  0.043090 -0.182490  0.015514
# 3      0.067134  0.063168  0.386055  0.023002  0.048363 -0.309135  0.004195
# 4     -0.010959  0.115632 -0.048844 -0.130186  0.229600 -0.207454  0.013241
# ...         ...       ...       ...       ...       ...       ...       ...
# 22220 -0.180867 -0.000074 -0.097486  0.138730  0.137916 -0.007709  0.017316
# 22221  0.072868 -0.055953  0.042459  0.036656  0.058271 -0.196131  0.020433
# 22222  0.114085 -0.105494  0.046369  0.136659  0.182144 -0.212911  0.126016
# 22223  0.175795 -0.047760  0.027296  0.038357  0.118579 -0.114327 -0.092380
# 22224  0.048273  0.004627  0.150644  0.021865  0.067533 -0.199626  0.100950
#
#             199
# 0     -0.056952
# 1     -0.148951
# 2     -0.233542
# 3     -0.173594
# 4     -0.216210
# ...         ...
# 22220 -0.166371
# 22221 -0.209770
# 22222  0.030037
# 22223  0.047048
# 22224 -0.239893
#
# [22225 rows x 203 columns]

# %%
data = train_data_model2.copy()
from sklearn.model_selection import train_test_split

y = data['price']
X = data.drop(columns=['price'])


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
X_train = X_train[:10000]
y_train = y_train[:10000]
X_test = X_test[:3500]
y_test = y_test[:3500]

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components=175)
X_K_train = kpca.fit_transform(X_train)
X_K_test = kpca.transform(X_test)

# %%
import pickle

# Load the MLP model from file
filename = 'sg_model1.pkl'
with open(filename, 'rb') as file:
    model1 = pickle.load(file)

# %%
import pickle

# Load the MLP model from file
filename = 'sg_model2.pkl'
with open(filename, 'rb') as file:
    model2 = pickle.load(file)

# %%
import pickle

# Load the MLP model from file
filename = 'sg_model3.pkl'
with open(filename, 'rb') as file:
    model3 = pickle.load(file)

# %%
import pickle

# Load the MLP model from file
filename = 'sg_model4.pkl'
with open(filename, 'rb') as file:
    model4 = pickle.load(file)

# %%
import pickle

# Load the MLP model from file
filename = 'sg_model5.pkl'
with open(filename, 'rb') as file:
    model5 = pickle.load(file)
# Out:
# [10:01:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:553:
#   If you are loading a serialized model (like pickle in Python, RDS in R) generated by
#   older XGBoost, please export the model by calling `Booster.save_model` from that version
#   first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/latest/tutorials/saving_model.html
#
#   for more details about differences between saving model and serializing.

# %%
import pickle

# Load the MLP model from file
filename = 'sg_model6.pkl'
with open(filename, 'rb') as file:
    model6 = pickle.load(file)

# %%
y1 = model1.predict(X_test)
y2 = model2.predict(X_K_test)
y3 = model3.predict(X_K_test)
y4 = model4.predict(X_test)
y5 = model5.predict(X_K_test)
model6.fit(X_K_train, y_train)
y6 = model6.predict(X_K_test)

# %%
y1.shape
# Out:
# (3500,)

# %%
plt.rcParams['lines.linewidth'] = 3

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y1[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y1[:100], label='Model 1', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value', zorder=2)
# Customize the plot
plt.title("Word2Vec(SG) - Multi-Layered Perceptron Regressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y2[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y2[:100], label='Model 2', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(SG) - Kernelized PCA - Multi-Layered Perceptron Regressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y3[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y3[:100], label='Model 3', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(SG) - Kernelized PCA - RandomizedSearchCV - Multi-Layered Perceptron Regressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y4[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y4[:100], label='Model 4', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(SG) - XGBRegressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y5[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y5[:100], label='Model 5', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(SG) - Kernelized PCA - XGBRegressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True, linewidth=1.5, which='both')
x= [i for i in range(100)]
plt.scatter(x, y6[:100])
plt.scatter(x, y_test[:100])
plt.plot(x, y6[:100], label='Model 6', zorder=3)
plt.plot(x, y_test[:100], label='Actual Value')

# Customize the plot
plt.title("Word2Vec(SG) - Kernelized PCA - RandomizedSearchCV - XGBRegressor")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True)
x= [i for i in range(100)]
plt.scatter(x, y1[:100])
plt.scatter(x, y2[:100])
plt.scatter(x, y3[:100])
plt.plot(x, y1[:100], label='Model 1')
plt.plot(x, y2[:100], label='Model 2')
plt.plot(x, y3[:100], label='Model 3')
plt.plot(x, y_test[:100], label='Actual Value', zorder=3)

# Customize the plot
plt.title("Comparing All the Multi-Layered Perceptron Regressor Models.")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.grid(True)
x= [i for i in range(100)]
plt.scatter(x, y4[:100])
plt.scatter(x, y5[:100])
plt.scatter(x, y6[:100])
plt.plot(x, y4[:100], label='Model 4')
plt.plot(x, y5[:100], label='Model 5')
plt.plot(x, y6[:100], label='Model 6')
plt.plot(x, y_test[:100], label='Actual Value', zorder=3)

# Customize the plot
plt.title("Comparing All the XGBRegressor Models")
plt.xlabel("Test Data Products")
plt.ylabel("Product Price")
plt.legend()

# Display the plot
plt.show()
